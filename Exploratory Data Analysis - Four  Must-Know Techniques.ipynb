# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("humans.csv")
data
# Out:
#          Height     Weight  Age  Gender
# 0    174.967142  76.996777   49    Male
# 1    168.617357  74.623168   50  Female
# 2    176.476885  70.298152   57    Male
# 3    185.230299  66.765316   30    Male
# 4    167.658466  73.491117   54  Female
# ..          ...        ...  ...     ...
# 995  167.188997  75.350751   37    Male
# 996  187.976865  69.867394   51    Male
# 997  176.408429  65.590627   57    Male
# 998  164.288210  69.184665   22  Female
# 999  175.725828  66.275487   57    Male
#
# [1000 rows x 4 columns]

# %%
# Box plot of the height column
plt.figure(figsize=(8, 6))
sns.boxplot(data['Height'], color='orange')
plt.title('Box plot of Height')
plt.xlabel('Height')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x= data['Height'], 
                y= data['Weight'], 
                data=data, color='blue')
plt.title('Scatter plot of Height vs. Weight')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
# Pairplot of Height, Weight, and Age
sns.pairplot(data[['Height', 'Weight', 'Age']])
plt.show()

# %%
# Creating a new variable BMI (Body Mass Index)
data['BMI'] = data['Weight'] / ((data['Height'] / 100) ** 2)
data.head()
# Out:
#        Height     Weight  Age  Gender        BMI
# 0  174.967142  76.996777   49    Male  25.151249
# 1  168.617357  74.623168   50  Female  26.246363
# 2  176.476885  70.298152   57    Male  22.571907
# 3  185.230299  66.765316   30    Male  19.459284
# 4  167.658466  73.491117   54  Female  26.144712
